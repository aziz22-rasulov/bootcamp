# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
np.round(df.describe(), 2)
# Out:
#        total_bill     tip    size  price_per_person     CC Number
# count      244.00  244.00  244.00            244.00  2.440000e+02
# mean        19.79    3.00    2.57              7.89  2.563496e+15
# std          8.90    1.38    0.95              2.91  2.369340e+15
# min          3.07    1.00    1.00              2.88  6.040679e+10
# 25%         13.35    2.00    2.00              5.80  3.040731e+13
# 50%         17.80    2.90    2.00              7.26  3.525318e+15
# 75%         24.13    3.56    3.00              9.39  4.553675e+15
# max         50.81   10.00    6.00             20.27  6.596454e+15

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df[((df['sex'].eq('Female')) & (df['total_bill'] >= 15)) & (df['day'].isin(['Sun', 'Sat']))]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 18        16.97  3.50  Female     No  Sun  Dinner     3              5.66
# 21        20.29  2.75  Female     No  Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No  Sat  Dinner     2              7.88
# 29        19.65  3.00  Female     No  Sat  Dinner     2              9.82
# 32        15.06  3.00  Female     No  Sat  Dinner     2              7.53
# 33        20.69  2.45  Female     No  Sat  Dinner     4              5.17
# 37        16.93  3.07  Female     No  Sat  Dinner     3              5.64
# 52        34.81  5.20  Female     No  Sun  Dinner     4              8.70
# 57        26.41  1.50  Female     No  Sat  Dinner     2             13.20
# ...

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
np.unique(df['day'], return_counts=True)
# Out:
# (array(['Fri', 'Sat', 'Sun', 'Thur'], dtype=object), array([19, 87, 76, 62]))

# %%
Три категориальных столбца, с значениями 0 и 1

total_bill < 10
total_bill от 10 до 20 (не вкл)
total_bill > 20
# Out:
#   Cell In[10], line 1
#     Три категориальных столбца, с значениями 0 и 1
#         ^
# SyntaxError: invalid syntax

# %%
df['cat_total_bill'] = df['total_bill'].apply(lambda x: 'lt_10' if x < 10 else \
                                'ge_10_lt_30' if 10 <= x < 30 else\
                                'ge 30')

# %%
total_bill -> lt_10 | median | avg

# %%
tdf = df[['total_bill', 'cat_total_bill']]

# %%
tdf
# Out:
#      total_bill cat_total_bill
# 0         16.99    ge_10_lt_30
# 1         10.34    ge_10_lt_30
# 2         21.01    ge_10_lt_30
# 3         23.68    ge_10_lt_30
# 4         24.59    ge_10_lt_30
# ..          ...            ...
# 239       29.03    ge_10_lt_30
# 240       27.18    ge_10_lt_30
# 241       22.67    ge_10_lt_30
# 242       17.82    ge_10_lt_30
# 243       18.78    ge_10_lt_30
#
# [244 rows x 2 columns]

# %%
tdf[tdf['cat_total_bill'].eq('lt_10')]
# Out:
#      total_bill cat_total_bill
# 6          8.77          lt_10
# 30         9.55          lt_10
# 43         9.68          lt_10
# 53         9.94          lt_10
# 67         3.07          lt_10
# 92         5.75          lt_10
# 111        7.25          lt_10
# 126        8.52          lt_10
# 135        8.51          lt_10
# 145        8.35          lt_10
# 148        9.78          lt_10
# 149        7.51          lt_10
# 172        7.25          lt_10
# 178        9.60          lt_10
# 195        7.56          lt_10
# 218        7.74          lt_10
# 222        8.58          lt_10

# %%
tdf[tdf['cat_total_bill'].eq('lt_10')].describe()
# Out:
#        total_bill
# count   17.000000
# mean     8.082941
# std      1.717119
# min      3.070000
# 25%      7.510000
# 50%      8.510000
# 75%      9.550000
# max      9.940000
